# %%
import pandas as pd
import pickle

import os
import numpy as np
import sys
import gensim
import matplotlib.pyplot as plt
sys.path.append(r'C:\Users\aspit\Git\MHDLab-Projects\Energy Storage\nlp_utils')

from nlp_utils import gensim_utils, sklearn_utils, fileio

df = fileio.load_df(r'C:\Users\aspit\Git\MHDLab-Projects\Energy Storage\data\nlp_justenergystorage_100.db')

texts = df['processed_text'].values
texts = [t.split() for t in texts]

# %%
n_topics = 200
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.1, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':50, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.115
# Median Normalized Topic Probability:0.002606334593838775

# %%
n_topics = 100
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.1, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':50, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.23
# Median Normalized Topic Probability:0.00458053542953544

# %%
n_topics = 100
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.1, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.21
# Median Normalized Topic Probability:0.004700977011214081

# %%
n_topics = 100
alpha = 25/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.1, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.19
# Median Normalized Topic Probability:0.003897911043102992

# %%
n_topics = 100
alpha = 10/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.1, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.18
# Median Normalized Topic Probability:0.0025744984247312794

# %%
n_topics = 100
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.25, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.11
# Median Normalized Topic Probability:0.004375734732748672

# %%
n_topics = 100
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.05, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.28
# Median Normalized Topic Probability:0.0076562870278734495

# %%
n_topics = 200
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.05, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.105
# Median Normalized Topic Probability:0.0030169391492789106

# %%
n_topics = 200
alpha = 50/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.01, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.05
# Median Normalized Topic Probability:0.0039470026260852754

# %%
n_topics = 200
alpha = 25/n_topics

lda_kwargs = {'alpha': alpha, 'eta': 0.01, 'num_topics':n_topics, 'passes':5}
bigram_kwargs =  {'min_count':20, 'threshold':100}

texts_bigram, id2word, data_words, lda_model = gensim_utils.gensim_lda_bigram(texts, bigram_kwargs, lda_kwargs)

df_topickeywords, doc_topic_probs = gensim_utils.gensim_topic_info(lda_model, data_words, id2word)
df_doc_topic_probs = pd.DataFrame(doc_topic_probs, columns=df_topickeywords.index, )
df_doc_topic_probs.index = range(doc_topic_probs.shape[0])

n_topics = doc_topic_probs.shape[1]

cum_prob = df_doc_topic_probs.sum()
cum_prob_norm = cum_prob/cum_prob.sum()
cum_prob_norm.hist(bins = n_topics)

pct_cutoff = 0.01
fraction_greater = cum_prob_norm[cum_prob_norm > pct_cutoff].count() / cum_prob_norm.count()
print("Fraction of topics with cumulative probability greater than " + str(pct_cutoff*100) + "% : " + str(fraction_greater))


print("Median Normalized Topic Probability:" + str(cum_prob_norm.median()) )
# Out:
# Fraction of topics with cumulative probability greater than 1.0% : 0.115
# Median Normalized Topic Probability:0.003128206047831557

# %%
num_bigrams, total_words = gensim_utils.bigram_stats(data_words, id2word)
bigram_fraction = num_bigrams/total_words
bigram_fraction
# metrics.append(bigram_fraction)
# Out:
# 0.006298365548113961

# %%
# Out:
# 0.002606334593838775
