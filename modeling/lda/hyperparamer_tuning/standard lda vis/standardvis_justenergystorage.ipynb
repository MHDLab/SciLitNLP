# %%
import xarray as xr
import xyzpy
import numpy as np
import sys
import os


sys.path.append(r'C:\Users\aspit\Git\MHDLab-Projects\Energy Storage\nlp_utils')

from nlp_utils import plot
from nlp_utils import gensim_utils
from nlp_utils import sklearn_utils

import sqlite3
import pandas as pd

data_folder = r'C:\Users\aspit\Git\MHDLab-Projects\Energy Storage\data'

con = sqlite3.connect(os.path.join(data_folder, 'nlp.db'))
cursor = con.cursor()

df = pd.read_sql_query("SELECT * FROM texts", con, index_col='ID')

# df = df.sample(500, random_state=1)
df = df.dropna(subset=['processed_text'])
df = df[df['language'] == 'en']



texts = df['processed_text'].values
texts = [t.split() for t in texts]

# %%
lda_kwargs = {'alpha': 0.7, 'eta': 0.9, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %% [markdown]
# I think the local minimum around 0.2 is better

# %%
lda_kwargs = {'alpha': 0.2, 'eta': 0.2, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.1, 'eta': 0.2, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.1, 'eta': 0.1, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.2, 'eta': 0.1, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %% [markdown]
# Increasing alpha

# %%
lda_kwargs = {'alpha': 0.3, 'eta': 0.1, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.4, 'eta': 0.1, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.5, 'eta': 0.1, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':100}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %% [markdown]
# Hiher amount of bigrams
#
# This appears to bring out the 'systems analysis' group

# %%
lda_kwargs = {'alpha': 0.2, 'eta': 0.2, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':50}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.5, 'eta': 0.2, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':50}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.5, 'eta': 0.3, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':50}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.4, 'eta': 0.2, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':50}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)

# %%
lda_kwargs = {'alpha': 0.4, 'eta': 0.3, 'num_topics':20, 'passes':5}
bigram_kwargs =  {'min_count':5, 'threshold':50}

fig = plot.topics_fig_bigramlda(texts, bigram_kwargs, lda_kwargs)
